# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %%
chunkSize = 5000
Data = pd.read_csv("/home/shivam/AI21Pandey/AI21/ai21/ai21/kaggleDataset/LANL-DataSet/train/train.csv", chunksize = chunkSize, dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})

# %%
i = 0
plt.figure(figsize=(44, 24))
for test in Data:
    test = test.iloc[:, :].values
    plt.subplot(6, 4, i+1)
    plt.plot(test[:, 0], color = 'green')
    plt.plot(test[:, 1]*10, color = 'blue')
    i += 1
    if (i == 24):
        break

# %%
i = 0
test1 = []
for test1 in Data:
    test1 = test1.iloc[:, :].values
    print(test1)
    plt.plot(test1[:, 1], color = 'blue')
    plt.show()
    i += 1
    if (i == 10):
        break
# plt.show()
# Out:
# [[ 8.         1.464896 ]
#  [ 9.         1.464896 ]
#  [11.         1.464896 ]
#  ...
#  [-1.         1.4627995]
#  [ 1.         1.4627995]
#  [ 1.         1.4627995]]
# [[ 0.         1.4627995]
#  [-2.         1.4627995]
#  [ 0.         1.4627995]
#  ...
#  [ 8.         1.4616985]
#  [ 7.         1.4616985]
#  [ 8.         1.4616985]]
# [[ 8.         1.4616985]
#  [12.         1.4616985]
#  [ 9.         1.4616985]
#  ...
#  [ 8.         1.4605975]
#  [ 7.         1.4605975]
#  [ 4.         1.4605975]]
# [[ 0.         1.4605975]
#  [ 3.         1.4605975]
#  [ 7.         1.4605975]
#  ...
#  [11.         1.4595965]
#  [13.         1.4595965]
#  [ 9.         1.4595965]]
# [[8.        1.4595965]
#  [6.        1.4595965]
#  [4.        1.4595965]
#  ...
#  [1.        1.4584955]
#  [5.        1.4584955]
#  [5.        1.4584955]]
# [[ 2.         1.4584955]
#  [ 0.         1.4584955]
#  [ 1.         1.4584955]
#  ...
#  [-3.         1.4563991]
#  [ 0.         1.4563991]
#  [ 6.         1.4563991]]
# [[1.        1.4563991]
#  [4.        1.4563991]
#  [9.        1.4563991]
#  ...
#  [8.        1.4552981]
#  [8.        1.4552981]
#  [5.        1.4552981]]
# [[3.        1.4552981]
#  [2.        1.4552981]
#  [7.        1.4552981]
#  ...
#  [4.        1.454197 ]
#  [6.        1.454197 ]
#  [4.        1.454197 ]]
# [[ 2.        1.454197]
#  [ 4.        1.454197]
#  [ 9.        1.454197]
#  ...
#  [14.        1.453196]
#  [14.        1.453196]
#  [14.        1.453196]]
# [[14.         1.453196 ]
#  [13.         1.453196 ]
#  [12.         1.453196 ]
#  ...
#  [ 2.         1.4510996]
#  [ 8.         1.4510996]
#  [ 9.         1.4510996]]
